# %% [markdown]
# # Pulses Of Light
# ## Introduction
# We have already had a look at how constant E field interact with a three level atom showing the susceptability, $\chi$, and *slow light*. Now we will look at how pulses of the probe beam interact with the atom and end up at *pulse distortion*.
# ## Imports

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import numpy as np
from scipy.optimize import curve_fit
from scipy.constants import c, e, hbar
from qutip import *
import matplotlib.patches as mpatches
from scipy import signal
from arc import *

# %matplotlib inline

# %%
rabi_probe = 0.001
rabi_couple = 1
detune_probe = 0
detune_couple = 0
gamma_b = 0.05
gamma_c = 0.001


#signal params
tau = 10E-6
slope = tau*2
gradient = rabi_probe/slope

# %% [markdown]
# ## Making the Pulse
# We will start with a trapezium pulse

# %%
times = np.linspace(0,1E-4,1000)

def trapzoid_signal(t, args):
    slope = args['slope']
    amp = args['A']
    width = args['width']
    offs = args['offs']
    a = slope*width*signal.sawtooth(2*np.pi*t/width, width=0.5)/4
    a[a>amp/2.] = amp/2.
    a[a<-amp/2.] = -amp/2.
    return a + amp/2. + offs

def get_trap(t,args):
    times = np.linspace(0,1E-4,1000)
    trap = trapzoid_signal(times,args)
    index = np.where(times == t)
    return trap[index]

args = {'A': rabi_probe, 'slope': gradient, 'width': 1E-4, 'offs': 0}
plt.plot(times,trapzoid_signal(times,args))

# %% [markdown]
# Using this pulse, the rabi frequencies, which are proportional to the strength of E field, $\epsilon$, can be modified in the existing Hamiltonian
# $$
# H = \frac{\hbar}{2}
# \begin{pmatrix}
# 0 & \Omega_p \times \epsilon & 0\\
# \Omega_p \times \epsilon & -2\Delta_p & \Omega_c\\
# 0 & \Omega_c & -2(\Delta_p-\Delta_c)
# \end{pmatrix}$$

# %%
H0 = 0.5*Qobj(np.array([[0,rabi_probe,0],[rabi_probe,-2*detune_probe,rabi_couple],[0,rabi_couple,-2*(detune_probe-detune_couple)]]))
H1 = 0.5*Qobj(np.array([[0,1,0],[1,0,0],[0,0,0]]))
H = [H0, [H1, get_trap]]
psi0 = (basis(3,0)).unit()
c_ops = [np.sqrt(gamma_b)*(qutip.three_level_atom.three_level_ops()[3].dag()),np.sqrt(gamma_c)*qutip.three_level_atom.three_level_ops()[4].dag()]
e_ops = [np.sqrt(2)*jmat(1,'x'),np.sqrt(2)*jmat(1,'y'),2*jmat(1,'z')-1]

# %%
args['width']
# Out:
# 0.0001

# %%
args = {'A': rabi_probe, 'slope': gradient, 'width': 1E-4, 'offs': 0}

result_me = mesolve(H, psi0, times, c_ops, e_ops, args=args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[144], line 3
#       1 args = {'A': rabi_probe, 'slope': gradient, 'width': 1E-4, 'offs': 0}
# ----> 3 result_me = mesolve(H, psi0, times, c_ops, e_ops, args=args)
#
# File ~\Anaconda3\envs\Rydberg\lib\site-packages\qutip\mesolve.py:244, in mesolve(H, rho0, tlist, c_ops, e_ops, args, options, progress_bar, _safe_mode)
#     241     v = rho0.full().ravel('F')
#     242     func(0., v, *ode_args) + v
# --> 244 res = _generic_ode_solve(func, ode_args, rho0, tlist, e_ops, options,
#     245                          progress_bar, dims=rho0.dims)
#     246 res.num_collapse = len(c_ops)
#     248 if e_ops_dict:
#
# File ~\Anaconda3\envs\Rydberg\lib\site-packages\qutip\mesolve.py:531, in _generic_ode_solve(func, ode_args, rho0, tlist, e_ops, opt, progress_bar, dims)
#     526             output.expect[m][t_idx] = expect_rho_vec(e_ops_data[m], r.y,
#     527                                                      e_ops[m].isherm
#     528                                                      and rho0.isherm)
#     530     if t_idx < n_tsteps - 1:
# --> 531         r.integrate(r.t + dt[t_idx])
#     533 progress_bar.finished()
#     535 if opt.store_final_state:
#
# File ~\Anaconda3\envs\Rydberg\lib\site-packages\scipy\integrate\_ode.py:431, in ode.integrate(self, t, step, relax)
#     428     mth = self._integrator.run
#     430 try:
# --> 431     self._y, self.t = mth(self.f, self.jac or (lambda: None),
#     432                           self._y, self.t, t,
#     433                           self.f_params, self.jac_params)
#     434 except SystemError as e:
#     435     # f2py issue with tuple returns, see ticket 1187.
#     436     raise ValueError(
#     437         'Function to integrate must not return a tuple.'
#     438     ) from e
#
# File ~\Anaconda3\envs\Rydberg\lib\site-packages\scipy\integrate\_ode.py:1007, in vode.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1003     jac = _vode_banded_jac_wrapper(jac, self.ml, jac_params)
#    1005 args = ((f, jac, y0, t0, t1) + tuple(self.call_args) +
#    1006         (f_params, jac_params))
# -> 1007 y1, t, istate = self.runner(*args)
#    1008 self.istate = istate
#    1009 if istate < 0:
#
# File ~\Anaconda3\envs\Rydberg\lib\site-packages\qutip\cy\cqobjevo.pyx:212, in qutip.cy.cqobjevo.CQobjEvo.mul_vec()
#
# File ~\Anaconda3\envs\Rydberg\lib\site-packages\qutip\cy\cqobjevo.pyx:679, in qutip.cy.cqobjevo.CQobjEvoTd._mul_vec()
#
# File ~\Anaconda3\envs\Rydberg\lib\site-packages\qutip\cy\cqobjevo.pyx:293, in qutip.cy.cqobjevo.CQobjEvo._factor_dyn()
#
# File ~\Anaconda3\envs\Rydberg\lib\site-packages\qutip\cy\cqobjevo.pyx:281, in qutip.cy.cqobjevo.CQobjEvo._factor()
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
plot_expectation_values(
    [result_me], ylabels=["<X>", "<Y>", "<Z>"], show_legend=True
);
